# %% [markdown]
# <a href="https://colab.research.google.com/github/zeynepyilmazz/DataScienceBootcamp/blob/main/04.DataVisualizationwithPython/03.VisualizationWithMatplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this assignment, you will make some plots about Corona. First, download the Coronavirus Source Data.
#
#
#
# * First, filter the data for four countries (Spain, France, Germany, Italy) and the last 100 days.
# *  Create a figure with two subplots. The left subplot will show total cases, and the right one will show total deaths for these countries
#
# * Set titles, X and Y labels, change the font, font size, and font color for each subplot.
# *  Change color, width, and type of lines.
#
#
# * Put a legend to bottom right.
# * Change the color and rotation of the X-axis ticks.
#
# * And set a title for the figure (not for the plots).

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('owid-covid-data.csv', parse_dates=["date"], low_memory=False)

# %%
covid = pd.DataFrame(columns=df.columns)
df = df[df['location'].isin(['Spain', 'France', 'Germany', 'Italy'])]
for group_name , group in df.groupby(by='location'):
  covid = pd.concat([covid,group[-125:]])

display(covid)
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 25014      FRA    Europe  ...           82.66                   0.901
# 25015      FRA    Europe  ...           82.66                   0.901
# 25016      FRA    Europe  ...           82.66                   0.901
# 25017      FRA    Europe  ...           82.66                   0.901
# 25018      FRA    Europe  ...           82.66                   0.901
# ...        ...       ...  ...             ...                     ...
# 64249      ESP    Europe  ...           83.56                   0.904
# 64250      ESP    Europe  ...           83.56                   0.904
# 64251      ESP    Europe  ...           83.56                   0.904
# 64252      ESP    Europe  ...           83.56                   0.904
# 64253      ESP    Europe  ...           83.56                   0.904
#
# [500 rows x 59 columns]

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
plt.title('COVID - 19 TOTAL CASE' , color = '#8B0000' , fontsize = 20 , family = 'serif' , style = 'normal')
plt.plot(covid[covid['location'] == 'Spain']['date'],covid[covid['location'] == 'Spain']['total_cases'] ,
         c = '#000080' , lw = 2 , ls = '-')
plt.plot(covid[covid['location'] == 'France']['date'],covid[covid['location'] == 'France']['total_cases'],
         c = '#FF7F00' , lw = 2 , ls = '-.')
plt.plot(covid[covid['location'] == 'Germany']['date'],covid[covid['location'] == 'Germany']['total_cases'],
         c = '#2E8B57' , lw = 2 , ls = ':')
plt.plot(covid[covid['location'] == 'Italy']['date'],covid[covid['location'] == 'Italy']['total_cases'],
         c = '#CD5B45' , lw = 2 , ls = '--')
plt.xlabel('DATE' , color = '#8B7D7B') 
plt.ylabel("TOTAL CASE" , color = '#8B7D7B')
plt.legend(['Spain','France','Germany','Italy'] , loc=4)
plt.xticks(rotation = 45 , color = '#8B3E2F')
plt.yticks(color = '#8B3E2F')

plt.subplot(1,2,2)
plt.title('COVID - 19 TOTAL DEATHS' , color = '#8B0000' , fontsize = 20 , family = 'serif' , style = 'normal')
plt.plot(covid[covid['location'] == 'Spain']['date'],covid[covid['location'] == 'Spain']['total_deaths'] ,
         c = '#000080' , lw = 2 , ls = '-')
plt.plot(covid[covid['location'] == 'France']['date'],covid[covid['location'] == 'France']['total_deaths'],
         c = '#FF7F00' , lw = 2 , ls = '-.')
plt.plot(covid[covid['location'] == 'Germany']['date'],covid[covid['location'] == 'Germany']['total_deaths'],
         c = '#2E8B57' , lw = 2 , ls = ':')
plt.plot(covid[covid['location'] == 'Italy']['date'],covid[covid['location'] == 'Italy']['total_deaths'],
         c = '#CD5B45' , lw = 2 , ls = '--')
plt.xlabel('DATE' , color = '#8B7D7B')
plt.ylabel("TOTAL DEATHS" , color = '#8B7D7B')
plt.legend(['Spain','France','Germany','Italy'] , loc=4)
plt.xticks(rotation = 45 , color = '#8B3E2F')
plt.yticks(color = '#8B3E2F')

plt.show()
